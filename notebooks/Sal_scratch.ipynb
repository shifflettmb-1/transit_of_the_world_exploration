# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_cities = pd.read_csv(r"C:\Coding\assignments\transit_of_the_world_exploration\data\cities.csv")
df_lines = pd.read_csv(r"C:\Coding\assignments\transit_of_the_world_exploration\data\lines.csv")
df_station_lines = pd.read_csv(r"C:\Coding\assignments\transit_of_the_world_exploration\data\station_lines.csv")
df_stations = pd.read_csv(r"C:\Coding\assignments\transit_of_the_world_exploration\data\stations.csv")
df_systems = pd.read_csv(r"C:\Coding\assignments\transit_of_the_world_exploration\data\systems.csv")
df_track_lines = pd.read_csv(r"C:\Coding\assignments\transit_of_the_world_exploration\data\track_lines.csv")
df_tracks = pd.read_csv(r"C:\Coding\assignments\transit_of_the_world_exploration\data\tracks.csv")

# %%
# df_cities.info()
# df_cities.sample(10)
df_cities = df_cities.drop(["country_state"], axis=1)
df_cities
# Out:
#       id       name                             coords  start_year   url_name  \
# 0      5   Aberdeen                 POINT(-2.15 57.15)      2017.0   aberdeen
# 1      6   Adelaide          POINT(138.6 -34.91666667)      2017.0   adelaide
# 2      7    Algiers               POINT(3 36.83333333)      2017.0    algiers
# 3      9     Ankara     POINT(32.91666667 39.91666667)      2017.0     ankara
# 4     16      Belém   POINT(-48.48333333 -1.466666667)      2017.0      belem
# ..   ...        ...                                ...         ...        ...
# 329  265     Nantes         POINT(-1.553889 47.217222)      1877.0     nantes
# 330  110  Stockholm           POINT(18.05 59.28333333)      1919.0  stockholm
# 331  266     Rennes         POINT(-1.680833 48.114167)      1897.0     rennes
# 332   15    Beijing     POINT(116.4166667 39.91666667)      1965.0    beijing
# 333   69     London  POINT(-0.08333333333 51.53333333)      1833.0     london
#
#        country
# 0     Scotland
# ...

# %%
df_lines.info()
df_lines.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1343 entries, 0 to 1342
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1343 non-null   int64
#  1   city_id            1343 non-null   int64
#  2   name               1343 non-null   object
#  3   url_name           1343 non-null   object
#  4   color              1343 non-null   object
#  5   system_id          1343 non-null   int64
#  6   transport_mode_id  926 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 73.6+ KB
#         id  city_id                  name                  url_name    color  \
# 691    823      114       Kasaibashi Line       823-kasaibashi-line  #5f0101
# 1060  1111        1            La Matanza           1111-la-matanza  #f3d379
# 124    118       69  Waterloo & City Line  118-waterloo-&-city-line  #50e3c2
# ...

# %%
df_station_lines = df_station_lines.drop(["updated_at", "id"], axis=1)
df_station_lines
# Out:
#        station_id  line_id  city_id                  created_at
# 0            7754      570       74         2017-11-21 00:00:00
# 1            7771      571       74         2017-11-21 00:00:00
# 2            7764      571       74         2017-11-21 00:00:00
# 3            7763      571       74         2017-11-21 00:00:00
# 4            7729      571       74         2017-11-21 00:00:00
# ...           ...      ...      ...                         ...
# 16237       16554     1454       91  2019-03-11 21:35:50.069711
# 16238       16555     1454       91  2019-03-11 21:36:13.073166
# 16239       16556     1454       91  2019-03-11 21:40:42.812162
# 16240       16557     1454       91  2019-03-11 21:42:15.280984
# 16241       16558     1454       91  2019-03-11 21:42:48.700022
#
# [16242 rows x 4 columns]

# %%
df_stations.info()
df_stations.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15794 entries, 0 to 15793
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          15794 non-null  int64
#  1   name        14248 non-null  object
#  2   geometry    15794 non-null  object
#  3   buildstart  14342 non-null  float64
#  4   opening     15721 non-null  float64
#  5   closure     15713 non-null  float64
#  6   city_id     15794 non-null  int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 863.9+ KB
#           id                          name  \
# 15046  15670                   Yamato-Yagi
# 3340     201                     Matta\n\n
# 7851    5527                      Tamagawa
# 7657    4875  Malakoff - Plateau de Vanves
# 11135  11404               Milano Bruzzano
# 5918    5636                 Daijingushita
# 3378     318              Antón Martín\n\n
# 13187  13508                      Paiporta
# ...

# %%
# df_systems.info()
# df_systems.sample(10)

# %%
df_track_lines.info()
df_track_lines.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9757 entries, 0 to 9756
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          9757 non-null   int64
#  1   section_id  9757 non-null   int64
#  2   line_id     9757 non-null   int64
#  3   created_at  9757 non-null   object
#  4   updated_at  9757 non-null   object
#  5   city_id     9757 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 457.5+ KB
#          id  section_id  line_id                  created_at  \
# 9459  10402       10261     1601  2019-02-21 21:41:57.597704
# 9065  10004        9556     1588  2019-02-16 19:25:57.508376
# 6512   3031        1661      440         2017-11-21 00:00:00
# 1369   5870        5931      997  2018-03-04 17:32:39.155377
# 9017   9909        9495     1550  2019-02-14 20:38:48.117744
# 3814    837        2881      612         2017-11-21 00:00:00
# ...

# %%
df_tracks.info()
df_tracks.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9271 entries, 0 to 9270
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          9271 non-null   int64
#  1   geometry    9271 non-null   object
#  2   buildstart  7663 non-null   float64
#  3   opening     9250 non-null   float64
#  4   closure     9240 non-null   float64
#  5   length      9271 non-null   int64
#  6   city_id     9271 non-null   int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 507.1+ KB
#          id                                           geometry  buildstart  \
# 7749   7062  LINESTRING(-1.3737829 47.709313,-1.3736914 47....         NaN
# 8754   9083  LINESTRING(-71.604380326477 -33.0469569984517,...      1952.0
# 7315  10094  LINESTRING(-4.4047006 55.9007891,-4.4046266 55...         0.0
# 3281   1782  LINESTRING(139.622753775297 35.4663952270978,1...      1928.0
# ...
